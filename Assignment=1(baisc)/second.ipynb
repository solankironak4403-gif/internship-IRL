# %%
# read an integer from input, keep prompting until a valid integer is entered
while True:
    s = input("Enter a number: ").strip()
    if s == "":
        print("No input provided. Please enter a number.")
        continue
    try:
        n = int(s)
        break
    except ValueError:
        print("Invalid integer. Please try again.")

print(n)
if n % 2 != 0:
    print("Weird")
elif n % 2 == 0 and n in range(2, 6):
    print("Not Weird")
elif n % 2 == 0 and n in range(6, 21):
    print("Weird")
elif n % 2 == 0 and n > 20:
    print("Not Weird")
# Out:
# No input provided. Please enter a number.
# No input provided. Please enter a number.
# 12
# Weird
